# %%
### Install & Import Packages ###

# pip install -upgrade setuptools --user
# pip install atlassian-python-api --user

from atlassian import Confluence
import pandas as pd

from pandas import DataFrame as df

import datetime
from datetime import datetime, timezone, timedelta
from pytz import timezone as tzpy

# %%
# ### Variables: Satya ###
# url_base = 'satyabhambhani21'
# email_admin = 'satyabhambhani21@gmail.com'
# apikey = 'ReaaJSjQCsZUYTbPkhE13EA5'

# %%
### Variables: Neha ###
url_base = 'satyabhambhani21'
email_admin = 'satyabhambhani21@gmail.com'
apikey = 'ReaaJSjQCsZUYTbPkhE13EA5'

# %%
### Admin ###
url_server = f'https://{url_base}.atlassian.net/wiki'

# my team members
email_sdsu = 'sbhambhani4651@sdsu.edu'
email_yahoo = 'satyab21@yahoo.in'

# %%
### Instantiate ###
confluence = Confluence(
    url=url_server, 
    username=email_admin, 
    password=apikey)

# %% [markdown]
# ## Get Data

# %%
### Get Data ###

spaces = confluence.get_all_spaces()
df_spaces = df(spaces['results'], columns=['id', 'key', 'name', 'status', 'type'])
df_spaces = df_spaces[df_spaces['type']=='global']
display(df_spaces)

list_space_page_details = []
for idx_s, row_s in df_spaces.iterrows():
    
    space_key = row_s['key']
    space_id = row_s['id']
    space_name = row_s['name']
    
    df_get_all_pages = df(confluence.get_all_pages_from_space(space=space_key))
#     display(df_get_all_pages)
    
    
    for idx_p, rp in df_get_all_pages.iterrows(): # row-p
        page_id = rp['id']
        page_title = rp['title']
        page_status = rp['status']
        
        history = confluence.history(page_id)        
        lastUpdated = history['lastUpdated']            
        lastUpdated_by = lastUpdated['by']
        createdBy = history['createdBy']
        
        lastUpdated_by_displayName = lastUpdated_by['displayName']
        lastUpdated_by_email = lastUpdated_by['email']
        lastUpdated_by_accountId = lastUpdated_by['accountId'] 
        
        lastUpdated_when = lastUpdated['when']
        lastUpdated_friendlyWhen = lastUpdated['friendlyWhen']
                
        createdBy_email = createdBy['email']
        createdBy_displayName = createdBy['displayName']
        
        createdDate = history['createdDate']
        
        dict_page = {
            'space_id' : space_id,
            'space_key' : space_key,
            'space_name' : space_name,
            
            'page_id' : page_id,
            'page_title' : page_title,
            'page_status' : page_status,
            
            'lastUpdated_by_displayName': lastUpdated_by_displayName,
            'lastUpdated_by_accountId' : lastUpdated_by_accountId,
            'lastUpdated_by_email' : lastUpdated_by_email,
            
            'lastUpdated_when' : lastUpdated_when,
            'lastUpdated_friendlyWhen' : lastUpdated_friendlyWhen,
            
            'createdBy_email' : createdBy_email,
            'createdBy_displayName' : createdBy_displayName,
            'createdDate' : createdDate       
        }
        list_space_page_details.append(dict_page)
        
# df_cf = (df(list_space_page_details))   
df_cf_col = [
    'space_id',
    'space_name',

    'page_title',

    'lastUpdated_friendlyWhen',
    'lastUpdated_by_displayName',
    'lastUpdated_by_email',
    'lastUpdated_when',
    'lastUpdated_by_accountId',
    
    'createdDate',
    'createdBy_displayName',
    'createdBy_email',
    
    'page_id',
    'space_key',
    'page_status'
]

df_cf = df(list_space_page_details, columns=df_cf_col)
display(df_cf)
# Out:
#        id      key         name   status    type
# 0  262154      DAT  datascience  current  global
# 1  196741      DOC     doc_data  current  global
# 2  196612  FINANCE      finance  current  global
#    space_id   space_name         page_title lastUpdated_friendlyWhen  \
# 0    262154  datascience       DS very nice        about 2 hours ago
# 1    262154  datascience   datascience Home        about 2 hours ago
# 2    262154  datascience  Data science nice        about 2 hours ago
# 3    196741     doc_data           doc_data        about 2 hours ago
# 4    196741     doc_data         doc_Data_2        about 2 hours ago
# 5    196741     doc_data         doc_Data_1        about 2 hours ago
# 6    196612      finance               SG&A        about 4 hours ago
# 7    196612      finance            finance        about 4 hours ago
# 8    196612      finance               COGS        about 4 hours ago
#
#   lastUpdated_by_displayName        lastUpdated_by_email  \
# 0                 Satya SDSU
# 1                 Satya SDSU
# 2            Satya Bhambhani  satyabhambhani21@gmail.com
# 3            Satya Bhambhani  satyabhambhani21@gmail.com
# 4                 Satya SDSU
# 5            Satya Bhambhani  satyabhambhani21@gmail.com
# 6            Satya Bhambhani  satyabhambhani21@gmail.com
# 7            Satya Bhambhani  satyabhambhani21@gmail.com
# 8            Satya Bhambhani  satyabhambhani21@gmail.com
#
#            lastUpdated_when  lastUpdated_by_accountId  \
# 0  2022-09-14T22:01:56.157Z  63222b42b0ac1ba7b871cb61
# 1  2022-09-14T21:45:42.078Z  63222b42b0ac1ba7b871cb61
# 2  2022-09-14T21:59:46.775Z  63222959c7601c8e4abf41de
# 3  2022-09-14T21:50:10.140Z  63222959c7601c8e4abf41de
# 4  2022-09-14T22:00:56.320Z  63222b42b0ac1ba7b871cb61
# 5  2022-09-14T21:51:20.480Z  63222959c7601c8e4abf41de
# 6  2022-09-14T19:41:40.605Z  63222959c7601c8e4abf41de
# 7  2022-09-14T19:26:13.985Z  63222959c7601c8e4abf41de
# 8  2022-09-14T19:31:39.577Z  63222959c7601c8e4abf41de
#
#                 createdDate createdBy_displayName             createdBy_email  \
# 0  2022-09-14T22:01:45.835Z            Satya SDSU
# 1  2022-09-14T21:45:42.078Z            Satya SDSU
# 2  2022-09-14T21:58:57.661Z            Satya SDSU
# 3  2022-09-14T21:50:08.931Z       Satya Bhambhani  satyabhambhani21@gmail.com
# 4  2022-09-14T22:00:43.054Z            Satya SDSU
# 5  2022-09-14T21:51:02.644Z       Satya Bhambhani  satyabhambhani21@gmail.com
# 6  2022-09-14T19:40:54.689Z       Satya Bhambhani  satyabhambhani21@gmail.com
# 7  2022-09-14T19:26:12.722Z       Satya Bhambhani  satyabhambhani21@gmail.com
# 8  2022-09-14T19:28:23.846Z       Satya Bhambhani  satyabhambhani21@gmail.com
#
#   page_id space_key page_status
# 0  196988       DAT     current
# 1  262340       DAT     current
# 2  557071       DAT     current
# 3  196944       DOC     current
# 4  327684       DOC     current
# 5  426010       DOC     current
# 6   65551   FINANCE     current
# 7  196693   FINANCE     current
# 8  262145   FINANCE     current

# %%
# # timezone

# ts = df_cf['lastUpdated_when'][0]
# (ts)

# utc = datetime.fromisoformat(ts[:-1]).astimezone(timezone.utc)
# pst = (utc.replace(tzinfo=timezone.utc).astimezone(tz=None))
# # pst = (utc.replace(tzinfo=timezone.utc).astimezone(timezone('US/Pacific')))

# pst

# pst = pst.astimezone(tzpy('US/Pacific'))
